# %%
import cv2 as cv
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv.imread('casava.jpg')

# %%
plt.imshow(img)

# %%
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img = cv.cvtColor(img, cv.COLOR_RGB2HSV)
plt.imshow(img, )

# %%
mystring = "sum"
add_up = eval(mystring)

# %%
add_up([1,23])
# Out:
# 24
