# %%
import numpy
import cv2 as cv
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dog = cv.imread("bull.jpg")
dog = cv.cvtColor(dog, cv.COLOR_BGR2RGB)
plt.imshow(dog)

# %%
#cv.imwrite("dog_head.jpg", head)
head = cv.imread("bull_head.jpg")
head = cv.cvtColor(head, cv.COLOR_BGR2RGB)
plt.imshow(head)

# %%
dog_copy = dog.copy()
res = cv.matchTemplate(dog_copy, head, cv.TM_CCORR)

# %%
print(result)
# Out:
# [[5.5932404e+10 5.5974183e+10 5.6016048e+10 ... 5.7284248e+10
#   5.7245430e+10 5.7206571e+10]
#  [5.5943557e+10 5.5985201e+10 5.6027091e+10 ... 5.7312203e+10
#   5.7273393e+10 5.7234514e+10]
#  [5.5954792e+10 5.5996522e+10 5.6038334e+10 ... 5.7340379e+10
#   5.7301488e+10 5.7262604e+10]
#  ...
#  [5.8227638e+10 5.8277147e+10 5.8326557e+10 ... 5.9909976e+10
#   5.9866796e+10 5.9824017e+10]
#  [5.8242785e+10 5.8292195e+10 5.8341573e+10 ... 5.9911561e+10
#   5.9868348e+10 5.9825521e+10]
#  [5.8258006e+10 5.8307375e+10 5.8356654e+10 ... 5.9913523e+10
#   5.9870155e+10 5.9827229e+10]]

# %%
plt.imshow(result)

# %%
full = cv.imread("bull.jpg")
full= cv.cvtColor(full_copy, cv.COLOR_BGR2RGB)

head = cv.imread("bull_head.jpg")
head = cv.cvtColor(head, cv.COLOR_BGR2RGB)


methods = ['cv.TM_CCOEFF', 'cv.TM_CCOEFF_NORMED', 'cv.TM_CCORR', 'cv.TM_CCORR_NORMED', 'cv.TM_SQDIFF', 'cv.TM_SQDIFF_NORMED']

# %%
for m in methods:
    #create a copy of full
    full_copy = full.copy()
    method = eval(m)
    
    res = cv.matchTemplate(full_copy, head, method)
    min_v, max_v, min_loc, max_loc = cv.minMaxLoc(res)
    
    if method in [cv.TM_SQDIFF, cv.TM_SQDIFF_NORMED]:
        top_left = min_loc #(x,y)
    else:
        top_left = max_loc
    
    height, width, channels = head.shape
    bottom_right = (top_left[0]+width, top_left[1]+height)
    
    cv.rectangle(full_copy, top_left, bottom_right, (255,0,0), 10)
    
    # plot
    plt.subplot(121)
    plt.imshow(res)
    plt.title("HEATMAP")
    
    
    plt.subplot(122)
    plt.imshow(full_copy)
    plt.title("DETECTION")
    
    plt.suptitle(m)
    plt.show()
    
    print('\n')
    print('\n')

# %%
#the eval function

# %%
a = [4,6,1]

sum(a)
# Out:
# 11

# %%
b = "sum"

b(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-ea83132e43cf> in <module>
#       1 b = "sum"
#       2
# ----> 3 b(a)
#
# TypeError: 'str' object is not callable

# %%
eval(b)(a)
# Out:
# 11

# %%
sum([8,9])
# Out:
# 17

# %%
eval("sum")([8,9])
# Out:
# 17
